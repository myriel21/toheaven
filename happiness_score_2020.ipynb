# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
hp_score20y = pd.read_csv('C:\Coding/Python3/2020.csv')

# %%
hp_score20y.head(10)
# Out:
#   Country name     Regional indicator  Ladder score  \
# 0      Finland         Western Europe        7.8087
# 1      Denmark         Western Europe        7.6456
# 2  Switzerland         Western Europe        7.5599
# 3      Iceland         Western Europe        7.5045
# 4       Norway         Western Europe        7.4880
# 5  Netherlands         Western Europe        7.4489
# 6       Sweden         Western Europe        7.3535
# 7  New Zealand  North America and ANZ        7.2996
# 8      Austria         Western Europe        7.2942
# 9   Luxembourg         Western Europe        7.2375
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
# ...

# %%
hp_score20y.shape
# Out:
# (153, 20)

# %%
# # c열과 d열을 계층적 인덱스로 변경
# # set_index() : 리스트 형식으로 , 계층순서대로 컬럼명
# hp_score_n = hp_score20y.set_index(['Regional indicator','Country name'])
# hp_score_n.head(20)
# Out:
#                                              Ladder score  \
# Regional indicator           Country name
# Western Europe               Finland               7.8087
#                              Denmark               7.6456
#                              Switzerland           7.5599
#                              Iceland               7.5045
#                              Norway                7.4880
#                              Netherlands           7.4489
#                              Sweden                7.3535
# North America and ANZ        New Zealand           7.2996
# Western Europe               Austria               7.2942
#                              Luxembourg            7.2375
# North America and ANZ        Canada                7.2321
#                              Australia             7.2228
# Western Europe               United Kingdom        7.1645
# Middle East and North Africa Israel                7.1286
# ...

# %%
pd.pivot_table(hp_score20y,index=['Regional indicator'])
# Out:
#                                     Dystopia + residual  \
# Regional indicator
# Central and Eastern Europe                     2.033282
# Commonwealth of Independent States             1.786795
# East Asia                                      1.568866
# Latin America and Caribbean                    2.308386
# Middle East and North Africa                   1.746049
# North America and ANZ                          2.199327
# South Asia                                     1.528265
# Southeast Asia                                 1.524672
# Sub-Saharan Africa                             2.039189
# Western Europe                                 2.163781
#
#                                     Explained by: Freedom to make life choices  \
# Regional indicator
# Central and Eastern Europe                                            0.447895
# Commonwealth of Independent States                                    0.464354
# ...

# %%
pd.pivot_table(hp_score20y,index=['Regional indicator','Country name','Ladder score'])
# Out:
#                                                                         Dystopia + residual  \
# Regional indicator                 Country name           Ladder score
# Central and Eastern Europe         Albania                4.8827                   1.640897
#                                    Bosnia and Herzegovina 5.6741                   2.167242
#                                    Bulgaria               5.1015                   1.294961
#                                    Croatia                5.5047                   1.676029
#                                    Czech Republic         6.9109                   2.796808
#                                    Estonia                6.0218                   1.629928
#                                    Hungary                6.0004                   2.121846
#                                    Kosovo                 6.3252                   2.736903
# ...

# %%
# 특정 value만 표시
pd.pivot_table(hp_score20y,index=['Regional indicator','Country name'],values=['Ladder score'])
# Out:
#                                                            Ladder score
# Regional indicator                 Country name
# Central and Eastern Europe         Albania                       4.8827
#                                    Bosnia and Herzegovina        5.6741
#                                    Bulgaria                      5.1015
#                                    Croatia                       5.5047
#                                    Czech Republic                6.9109
#                                    Estonia                       6.0218
#                                    Hungary                       6.0004
#                                    Kosovo                        6.3252
#                                    Latvia                        5.9500
#                                    Lithuania                     6.2155
#                                    Macedonia                     5.1598
# ...

# %%
# pd.pivot_table(hp_score20y,index=['Regional indicator','Country name'],values=['Ladder score'],aggfunc=np.mean)
# Out:
#                                                            Ladder score
# Regional indicator                 Country name
# Central and Eastern Europe         Albania                       4.8827
#                                    Bosnia and Herzegovina        5.6741
#                                    Bulgaria                      5.1015
#                                    Croatia                       5.5047
#                                    Czech Republic                6.9109
#                                    Estonia                       6.0218
#                                    Hungary                       6.0004
#                                    Kosovo                        6.3252
#                                    Latvia                        5.9500
#                                    Lithuania                     6.2155
#                                    Macedonia                     5.1598
# ...

# %%
pd.pivot_table(hp_score20y,index=['Regional indicator','Country name'],
               values=['Ladder score'],
               aggfunc=[np.sum, np.mean],
              fill_value=0)
# Out:
#                                                                    sum  \
#                                                           Ladder score
# Regional indicator                 Country name
# Central and Eastern Europe         Albania                      4.8827
#                                    Bosnia and Herzegovina       5.6741
#                                    Bulgaria                     5.1015
#                                    Croatia                      5.5047
#                                    Czech Republic               6.9109
#                                    Estonia                      6.0218
#                                    Hungary                      6.0004
#                                    Kosovo                       6.3252
#                                    Latvia                       5.9500
#                                    Lithuania                    6.2155
# ...

# %%
continent_score =pd.pivot_table(hp_score20y,index=['Regional indicator'],
               values=['Country name','Ladder score'],
               aggfunc=[np.mean],
              fill_value=0)
continent_score
# Out:
#                                            mean
#                                    Ladder score
# Regional indicator
# Central and Eastern Europe             5.883818
# Commonwealth of Independent States     5.358342
# East Asia                              5.714850
# Latin America and Caribbean            5.981786
# Middle East and North Africa           5.227159
# North America and ANZ                  7.173525
# South Asia                             4.475443
# Southeast Asia                         5.383367
# Sub-Saharan Africa                     4.383495
# Western Europe                         6.899219

# %%
# continent_score.rename(columns={continent_score.columns[0]:'행복지수 평균'}, inplace= True)
# continent_score
# Out:
#                                            mean
#                                    Ladder score
# Regional indicator
# Central and Eastern Europe             5.883818
# Commonwealth of Independent States     5.358342
# East Asia                              5.714850
# Latin America and Caribbean            5.981786
# Middle East and North Africa           5.227159
# North America and ANZ                  7.173525
# South Asia                             4.475443
# Southeast Asia                         5.383367
# Sub-Saharan Africa                     4.383495
# Western Europe                         6.899219

# %%
continent_score.sort_values(by=continent_score.columns[0], ascending=False)
# Out:
#                                            mean
#                                    Ladder score
# Regional indicator
# North America and ANZ                  7.173525
# Western Europe                         6.899219
# Latin America and Caribbean            5.981786
# Central and Eastern Europe             5.883818
# East Asia                              5.714850
# Southeast Asia                         5.383367
# Commonwealth of Independent States     5.358342
# Middle East and North Africa           5.227159
# South Asia                             4.475443
# Sub-Saharan Africa                     4.383495
